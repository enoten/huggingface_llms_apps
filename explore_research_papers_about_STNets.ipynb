# %% [markdown]
# ## 1. Read PDF files with research papers using Llama-Index

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings, SimpleDirectoryReader, VectorStoreIndex
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor

# %%
import os
import time
import pandas as pd

# %% [markdown]
# <b>1.1 Setup model for embeddings</b>

# %%
# import any embedding model on HF hub (https://huggingface.co/spaces/mteb/leaderboard)
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Settings.embed_model = HuggingFaceEmbedding(model_name="thenlper/gte-large") # alternative model

Settings.llm = None
Settings.chunk_size = 256
Settings.chunk_overlap = 25
# Out:
# LLM is explicitly disabled. Using MockLLM.

# %% [markdown]
# <b>1.2 Read files one by one from the directory</b>

# %%
reader = SimpleDirectoryReader(input_dir="stnets", recursive=True)
reader.__dict__
# Out:
# {'fs': <fsspec.implementations.local.LocalFileSystem at 0x1f3d6bc0580>,
#  'errors': 'ignore',
#  'encoding': 'utf-8',
#  'exclude': None,
#  'recursive': True,
#  'exclude_hidden': True,
#  'required_exts': None,
#  'num_files_limit': None,
#  'raise_on_error': False,
#  'input_dir': WindowsPath('stnets'),
#  'input_files': [WindowsPath('C:/Users/18623/Desktop/PhiAi/Jupyter/stnets/Applications_of_the_Streaming_Networks.pdf'),
#   WindowsPath('C:/Users/18623/Desktop/PhiAi/Jupyter/stnets/arxiv_streaming_networks_ext.pdf'),
#   WindowsPath('C:/Users/18623/Desktop/PhiAi/Jupyter/stnets/cvpr2020.pdf'),
#   WindowsPath('C:/Users/18623/Desktop/PhiAi/Jupyter/stnets/Streaming_Networks_Enable_A_Robust_Classification_.pdf')],
#  'file_extractor': {},
#  'file_metadata': <llama_index.core.readers.file.base._DefaultFileMetadataFunc at 0x1f3b11d22e0>,
#  'filename_as_id': False}

# %% [markdown]
# <b>1.3 Store Text chunks in a dict to trace chunk-paper mapping</b>

# %%
pdf_files = reader.__dict__['input_files']
all_docs = []
doc_dict = {}
for i,docs in enumerate(reader.iter_data()):
    pdf_name = os.path.basename(pdf_files[i])
    print(f'Extract from file {pdf_name}')
    if pdf_name in doc_dict:
        doc_dict[pdf_name] += [docs]
    else:
        doc_dict[pdf_name] = [docs]
    all_docs.extend(docs)
# Out:
# Extract from file Applications_of_the_Streaming_Networks.pdf
# Extract from file arxiv_streaming_networks_ext.pdf
# Extract from file cvpr2020.pdf
# Extract from file Streaming_Networks_Enable_A_Robust_Classification_.pdf

# %% [markdown]
# <b>1.4 Inspect Llama-Index document class</b>

# %%
doc_dict['Applications_of_the_Streaming_Networks.pdf'][0][0].__dict__
# Out:
# {'id_': '2f5ab9e9-5989-44dc-b555-f6898eaa1ffb',
#  'embedding': None,
#  'metadata': {'page_label': '1',
#   'file_name': 'Applications_of_the_Streaming_Networks.pdf',
#   'file_path': 'C:\\Users\\18623\\Desktop\\PhiAi\\Jupyter\\stnets\\Applications_of_the_Streaming_Networks.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 1175055,
#   'creation_date': '2024-12-03',
#   'last_modified_date': '2024-12-03'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'text': 'See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/publication/340225121\nApplications of the Streaming Networks\nConference Paper · March 2020\nCITATIONS\n2\nREADS\n211\n2 authors:\nSergey Tarasenko\n34 PUBLICATIONS\xa0\xa0\xa033 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nFumihiko Takahashi\nJapanTaxi Co.,Ltd.\n6 PUBLICATIONS\xa0\xa0\xa03 CITATIONS\xa0\xa0\xa0\nSEE PROFILE\nAll content following this page was uploaded by Sergey Tarasenko on 27 March 2020.\nThe user has requested enhancement of the downloaded file.',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %% [markdown]
# <b>1.5 Get total number of collected chunks</b>

# %%
len(all_docs)
# Out:
# 37

# %% [markdown]
# <b>1.6 Preprocess chunk to drop first page and  Reshape a way to store the Llama-index docs</b>

# %%
articles = list(doc_dict.keys())

for key in articles:
    clean_docs = []
    for doc in doc_dict[key][0]:
        if 'See discussions, stats' in doc.text:
            continue
        clean_docs.append(doc)
    doc_dict[key] = clean_docs

# %% [markdown]
# <b>1.7 Get chuck distribution accross papers</b>

# %%
for key in doc_dict:
    num_chunks = len(doc_dict[key])
    print(f'{key} >>> {num_chunks} chunks')
# Out:
# Applications_of_the_Streaming_Networks.pdf >>> 4 chunks
# arxiv_streaming_networks_ext.pdf >>> 17 chunks
# cvpr2020.pdf >>> 3 chunks
# Streaming_Networks_Enable_A_Robust_Classification_.pdf >>> 10 chunks

# %% [markdown]
# <b>1.8 Collect all chunks for for each paper in one text</b>

# %%
articles = list(doc_dict.keys())
papers = {} 

for paper_name in articles:
    papers[paper_name] = ''
    for doc in doc_dict[paper_name]:
        papers[paper_name] += ' ' + doc.text

# %%
for paper_name in articles:
    papers[paper_name] = papers[paper_name].replace('.\n','. ')
    papers[paper_name] = papers[paper_name].replace('\n',' ')

# %%
#papers[articles[3]]

# %% [markdown]
# ## 2. Get Research Paper Summary

# %%
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("google/bigbird-pegasus-large-arxiv")

# by default encoder-attention is `block_sparse` with num_random_blocks=3, block_size=64
#model = BigBirdPegasusForConditionalGeneration.from_pretrained("google/bigbird-pegasus-large-arxiv")

# decoder attention type can't be changed & will be "original_full"
# you can change `attention_type` (encoder only) to full attention like this:
model = BigBirdPegasusForConditionalGeneration.from_pretrained("google/bigbird-pegasus-large-arxiv", 
                                                               attention_type="original_full")

# you can change `block_size` & `num_random_blocks` like this:
#model = BigBirdPegasusForConditionalGeneration.from_pretrained("google/bigbird-pegasus-large-arxiv", block_size=16, num_random_blocks=2)

# %% [markdown]
# <b>2.1 Summarize Papers</b>

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#pipe = pipeline(task="image-to-image", model="caidas/swin2SR-lightweight-x2-64", device=device)

# %%
summary_list = []
processed_papers = []
for i,paper in enumerate(articles):
    try:
        print(f'{i+1}/{len(articles)} process paper {paper}')
        time_start = time.time()
        inputs = tokenizer(papers[paper], return_tensors='pt')
        prediction = model.generate(**inputs)
        prediction = tokenizer.batch_decode(prediction)
        end_start = time.time()
        #print()
        print(f'Time taken {end_start - time_start}')
        #print(f'SUMMARY of {articles[0]}: \n {prediction}')
        processed_papers.append(paper)
        summary_list.append(prediction)
    except:
        print(f' >> SKIP: paper is tooo long')
# Out:
# 1/4 process paper Applications_of_the_Streaming_Networks.pdf
# Token indices sequence length is longer than the specified maximum sequence length for this model (8810 > 4096). Running this sequence through the model will result in indexing errors
# Time taken 72.80806946754456
# 2/4 process paper arxiv_streaming_networks_ext.pdf
#  >> SKIP: paper is tooo long
# 3/4 process paper cvpr2020.pdf
# Time taken 57.43613600730896
# 4/4 process paper Streaming_Networks_Enable_A_Robust_Classification_.pdf
#  >> SKIP: paper is tooo long

# %%
df_summary = pd.DataFrame({'paper':processed_papers,
                           'summary':summary_list
                          })

# %%
df_summary['summary'].values
# Out:
# array([list(['<s> in this paper , we present a new method for the classification of images of arbitrary shape and texture .<n> the method is based on the decomposition of the image into a sum of two parts .<n> the first part is a linear combination of a wavelet transform of the image and the second part is a projection of the wavelet function onto the subspace spanned by the input and the output of the wavelet .<n> we demonstrate the performance of the method by applying it to the problem of image classification . <n> [ [ section ] ] in this paper , we present a new method for the classification of images of arbitrary shape and texture .<n> the method is based on the decomposition of the image into a sum of a wavelet transform of the image and the second part is a projection of the wavelet function onto the subspace spanned by the input and the output of the wavelet .<n> we demonstrate the performance of the method by applying it to the problem of image classification . <n> [ [ section ] ] in this paper , we present a new method for the classification of images of arbitrary shape and texture .<n> the method is based on the decomposition of the image into a sum of a wavelet']),
#        list(['<s> in this paper , we show that the wavelet transform of an image can be used to determine the wavelet transform of the image .<n> we show that the wavelet transform of an image can be used to determine the wavelet transform of the image .<n> we show that the wavelet transform of an image can be used to determine the wavelet transform of the image . <n> [ [ section ] ] in this paper , we show that the wavelet transform of an image can be used to determine the wavelet transform of the image .<n> we show that the wavelet transform of an image can be used to determine the wavelet transform of the image . <n> [ [ section ] ] in this paper , we show that the wavelet transform of an image can be used to determine the wavelet transform of the image .<n> we show that the wavelet transform of an image can be used to determine the wavelet transform of the image . <n> [ [ section ] ] in this paper , we show that the wavelet transform of an image can be used to determine the wavelet transform of the image .<n> we show that the wavelet transform of an image can'])],
#       dtype=object)

# %% [markdown]
# ## 3. QA: Ask questions about the papers

# %% [markdown]
# <b>3.1 Roberta-base-sqaud2-distilled model</b>

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

# %%
dfs = {}

# %%
model_name = "deepset/roberta-base-squad2-distilled"

# a) Get predictions
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
nlp = pipeline('question-answering', 
               model=model_name, 
               tokenizer=model_name,
               device = device
              )

# %%
answer_list = []
score_list = []
for paper in articles:
    question = 'How to describe STNet in short?'
    QA_input = {
        'question': question,
        'context': papers[paper]
    }
    res = nlp(QA_input)
    #print(f'from paper {paper} \n we learn that answer to {question} is \n {res} \n')
    answer_list.append(res['answer'])
    score_list.append(res['score'])

dfs[question + model_name] = pd.DataFrame({'question':len(articles)*[question],
                                           'model name':len(articles)*[model_name],
                                           'paper':articles,
                                           'answer': answer_list,
                                           'score':score_list
                             })
dfs[question + model_name]
# Out:
# C:\Users\18623\anaconda3\envs\transformers\lib\site-packages\transformers\pipelines\question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# C:\Users\18623\anaconda3\envs\transformers\lib\site-packages\transformers\models\roberta\modeling_roberta.py:370: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
#                           question                             model name  \
# 0  How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 1  How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 2  How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 3  How to describe STNet in short?  deepset/roberta-base-squad2-distilled
#
#                                                paper                answer  \
# 0         Applications_of_the_Streaming_Networks.pdf  Streaming net- works
# 1                   arxiv_streaming_networks_ext.pdf     Streaming Network
# 2                                       cvpr2020.pdf    Streaming networks
# 3  Streaming_Networks_Enable_A_Robust_Classificat...       pseudo-conv net
#
#       score
# 0  0.581112
# 1  0.114451
# 2  0.267675
# 3  0.539523

# %%
answer_list = []
score_list = []
for paper in articles:
    question = 'what is main advantage of STNets?'
    QA_input = {
        'question': question,
        'context': papers[paper]
    }
    res = nlp(QA_input)
    #print(f'from paper {paper} \n we learn that answer to {question} is \n {res} \n')
    answer_list.append(res['answer'])
    score_list.append(res['score'])

dfs[question + model_name] = pd.DataFrame({'question':len(articles)*[question],
                              'model name':len(articles)*[model_name],
                              'paper':articles,
                              'answer': answer_list,
                              'score':score_list
                             })
dfs[question + model_name]
# Out:
# C:\Users\18623\anaconda3\envs\transformers\lib\site-packages\transformers\pipelines\question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
#                             question                             model name  \
# 0  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 1  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 2  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 3  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
#
#                                                paper  \
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                                               answer     score
# 0  robust recognition of corrupted images under v...  0.382967
# 1                                   noise robustness  0.874971
# 2  recognizing zero noise- corrupted images with ...  0.342385
# 3                       state-of-the-art performance  0.315538

# %%
answer_list = []
score_list = []
for paper in articles:
    question = 'what are key features of STNets?'
    QA_input = {
        'question': question,
        'context': papers[paper]
    }
    res = nlp(QA_input)
    #print(f'from paper {paper} \n we learn that answer to {question} is \n {res} \n')
    answer_list.append(res['answer'])
    score_list.append(res['score'])

dfs[question + model_name] = pd.DataFrame({'question':len(articles)*[question],
                              'model name':len(articles)*[model_name],
                              'paper':articles,
                              'answer': answer_list,
                              'score':score_list
                             })
dfs[question + model_name]
# Out:
# C:\Users\18623\anaconda3\envs\transformers\lib\site-packages\transformers\pipelines\question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#                            question                             model name  \
# 0  what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 1  what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 2  what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 3  what are key features of STNets?  deepset/roberta-base-squad2-distilled
#
#                                                paper  \
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                                               answer     score
# 0  capable of recognition of zero noise- corrupte...  0.066198
# 1             hard- wired and input-induced sparsity  0.669279
# 2  capable of recognizing zero noise- corrupted i...  0.316081
# 3                           images without any noise  0.009240

# %% [markdown]
# <b>3.2 HuggingFace examplar pipeline</b>

# %%
qa_model = pipeline("question-answering", 
                    device=device)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
answer_list = []
score_list = []
for paper in articles:
    question = 'what is main advantage of STNets?'
    res = qa_model(question = question, context = papers[paper])
    #print(f'from paper {paper} \n we learn that answer to {question} is \n {res} \n')
    answer_list.append(res['answer'])
    score_list.append(res['score'])

dfs[question+'_nomodel'] = pd.DataFrame({'question':len(articles)*[question],
                                         'model name': len(articles)*['default'],
                                         'paper':articles,
                                         'answer': answer_list,
                                         'score':score_list
                                        })
dfs[question+'_nomodel']
# Out:
#                             question model name  \
# 0  what is main advantage of STNets?    default
# 1  what is main advantage of STNets?    default
# 2  what is main advantage of STNets?    default
# 3  what is main advantage of STNets?    default
#
#                                                paper  \
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                                            answer     score
# 0                recognition of low- light images  0.111861
# 1                                 higher capacity  0.696631
# 2                               moderate accuracy  0.185213
# 3  increase conv net robustness against the noise  0.166835

# %%
answer_list = []
score_list = []
for paper in articles:
    question = 'How to describe STNet in short?'
    res = qa_model(question = question, context = papers[paper])
    #print(f'from paper {paper} \n we learn that answer to {question} is \n {res} \n')
    answer_list.append(res['answer'])
    score_list.append(res['score'])

dfs[question+'_nomodel'] = pd.DataFrame({'question':len(articles)*[question],
                                         'model name': len(articles)*['default'],
                                         'paper':articles,
                                         'answer': answer_list,
                                         'score':score_list
                                        })
dfs[question+'_nomodel']
# Out:
#                           question model name  \
# 0  How to describe STNet in short?    default
# 1  How to describe STNet in short?    default
# 2  How to describe STNet in short?    default
# 3  How to describe STNet in short?    default
#
#                                                paper  \
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                         answer     score
# 0                hybrid STnets  0.570117
# 1  Kullback–Leibler divergence  0.302576
# 2                    5- stream  0.726802
# 3                Streaming Net  0.474929

# %%
answer_list = []
score_list = []
for paper in articles:
    question = 'what are key features of STNets?'
    res = qa_model(question = question, context = papers[paper])
    #print(f'from paper {paper} \n we learn that answer to {question} is \n {res} \n')
    answer_list.append(res['answer'])
    score_list.append(res['score'])

dfs[question+'_nomodel'] = pd.DataFrame({'question':len(articles)*[question],
                                         'model name': len(articles)*['default'],
                                         'paper':articles,
                                         'answer': answer_list,
                                         'score':score_list
                                        })
dfs[question+'_nomodel']
# Out:
#                            question model name  \
# 0  what are key features of STNets?    default
# 1  what are key features of STNets?    default
# 2  what are key features of STNets?    default
# 3  what are key features of STNets?    default
#
#                                                paper  \
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                                               answer     score
# 0  lighting or weather condition, speed, distance...  0.537666
# 1                                    higher capacity  0.316742
# 2  capable of recognizing zero noise- corrupted i...  0.059329
# 3       Spike- based strategies for rapid processing  0.192970

# %% [markdown]
# <b>3.3 Summarize QA results in one DataFrame</b>

# %%
qa_keys = list(dfs.keys())

merged_df = pd.concat([dfs[key] for key in qa_keys])

# %%
merged_df
# Out:
#                             question                             model name  \
# 0    How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 1    How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 2    How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 3    How to describe STNet in short?  deepset/roberta-base-squad2-distilled
# 0  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 1  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 2  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 3  what is main advantage of STNets?  deepset/roberta-base-squad2-distilled
# 0   what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 1   what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 2   what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 3   what are key features of STNets?  deepset/roberta-base-squad2-distilled
# 0  what is main advantage of STNets?                                default
# 1  what is main advantage of STNets?                                default
# 2  what is main advantage of STNets?                                default
# 3  what is main advantage of STNets?                                default
# 0    How to describe STNet in short?                                default
# 1    How to describe STNet in short?                                default
# 2    How to describe STNet in short?                                default
# 3    How to describe STNet in short?                                default
# 0   what are key features of STNets?                                default
# 1   what are key features of STNets?                                default
# 2   what are key features of STNets?                                default
# 3   what are key features of STNets?                                default
#
#                                                paper  \
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
# 0         Applications_of_the_Streaming_Networks.pdf
# 1                   arxiv_streaming_networks_ext.pdf
# 2                                       cvpr2020.pdf
# 3  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                                               answer     score
# 0                               Streaming net- works  0.581112
# 1                                  Streaming Network  0.114451
# 2                                 Streaming networks  0.267675
# 3                                    pseudo-conv net  0.539523
# 0  robust recognition of corrupted images under v...  0.382967
# 1                                   noise robustness  0.874971
# 2  recognizing zero noise- corrupted images with ...  0.342385
# 3                       state-of-the-art performance  0.315538
# 0  capable of recognition of zero noise- corrupte...  0.066198
# 1             hard- wired and input-induced sparsity  0.669279
# 2  capable of recognizing zero noise- corrupted i...  0.316081
# 3                           images without any noise  0.009240
# 0                   recognition of low- light images  0.111861
# 1                                    higher capacity  0.696631
# 2                                  moderate accuracy  0.185213
# 3     increase conv net robustness against the noise  0.166835
# 0                                      hybrid STnets  0.570117
# 1                        Kullback–Leibler divergence  0.302576
# 2                                          5- stream  0.726802
# 3                                      Streaming Net  0.474929
# 0  lighting or weather condition, speed, distance...  0.537666
# 1                                    higher capacity  0.316742
# 2  capable of recognizing zero noise- corrupted i...  0.059329
# 3       Spike- based strategies for rapid processing  0.192970

# %%
merged_df = merged_df.reset_index()
cols = list(merged_df.columns)
print(cols)
cols.remove('index')
merged_df = merged_df.groupby(['question','model name'])[cols].apply(lambda x: x)
# Out:
# ['index', 'question', 'model name', 'paper', 'answer', 'score']

# %%
merged_df
# Out:
#                                                                                                      question  \
# question                          model name
# How to describe STNet in short?   deepset/roberta-base-squad2-distilled 0     How to describe STNet in short?
#                                                                         1     How to describe STNet in short?
#                                                                         2     How to describe STNet in short?
#                                                                         3     How to describe STNet in short?
#                                   default                               16    How to describe STNet in short?
#                                                                         17    How to describe STNet in short?
#                                                                         18    How to describe STNet in short?
#                                                                         19    How to describe STNet in short?
# what are key features of STNets?  deepset/roberta-base-squad2-distilled 8    what are key features of STNets?
#                                                                         9    what are key features of STNets?
#                                                                         10   what are key features of STNets?
#                                                                         11   what are key features of STNets?
#                                   default                               20   what are key features of STNets?
#                                                                         21   what are key features of STNets?
#                                                                         22   what are key features of STNets?
#                                                                         23   what are key features of STNets?
# what is main advantage of STNets? deepset/roberta-base-squad2-distilled 4   what is main advantage of STNets?
#                                                                         5   what is main advantage of STNets?
#                                                                         6   what is main advantage of STNets?
#                                                                         7   what is main advantage of STNets?
#                                   default                               12  what is main advantage of STNets?
#                                                                         13  what is main advantage of STNets?
#                                                                         14  what is main advantage of STNets?
#                                                                         15  what is main advantage of STNets?
#
#                                                                                                        model name  \
# question                          model name
# How to describe STNet in short?   deepset/roberta-base-squad2-distilled 0   deepset/roberta-base-squad2-distilled
#                                                                         1   deepset/roberta-base-squad2-distilled
#                                                                         2   deepset/roberta-base-squad2-distilled
#                                                                         3   deepset/roberta-base-squad2-distilled
#                                   default                               16                                default
#                                                                         17                                default
#                                                                         18                                default
#                                                                         19                                default
# what are key features of STNets?  deepset/roberta-base-squad2-distilled 8   deepset/roberta-base-squad2-distilled
#                                                                         9   deepset/roberta-base-squad2-distilled
#                                                                         10  deepset/roberta-base-squad2-distilled
#                                                                         11  deepset/roberta-base-squad2-distilled
#                                   default                               20                                default
#                                                                         21                                default
#                                                                         22                                default
#                                                                         23                                default
# what is main advantage of STNets? deepset/roberta-base-squad2-distilled 4   deepset/roberta-base-squad2-distilled
#                                                                         5   deepset/roberta-base-squad2-distilled
#                                                                         6   deepset/roberta-base-squad2-distilled
#                                                                         7   deepset/roberta-base-squad2-distilled
#                                   default                               12                                default
#                                                                         13                                default
#                                                                         14                                default
#                                                                         15                                default
#
#                                                                                                                         paper  \
# question                          model name
# How to describe STNet in short?   deepset/roberta-base-squad2-distilled 0          Applications_of_the_Streaming_Networks.pdf
#                                                                         1                    arxiv_streaming_networks_ext.pdf
#                                                                         2                                        cvpr2020.pdf
#                                                                         3   Streaming_Networks_Enable_A_Robust_Classificat...
#                                   default                               16         Applications_of_the_Streaming_Networks.pdf
#                                                                         17                   arxiv_streaming_networks_ext.pdf
#                                                                         18                                       cvpr2020.pdf
#                                                                         19  Streaming_Networks_Enable_A_Robust_Classificat...
# what are key features of STNets?  deepset/roberta-base-squad2-distilled 8          Applications_of_the_Streaming_Networks.pdf
#                                                                         9                    arxiv_streaming_networks_ext.pdf
#                                                                         10                                       cvpr2020.pdf
#                                                                         11  Streaming_Networks_Enable_A_Robust_Classificat...
#                                   default                               20         Applications_of_the_Streaming_Networks.pdf
#                                                                         21                   arxiv_streaming_networks_ext.pdf
#                                                                         22                                       cvpr2020.pdf
#                                                                         23  Streaming_Networks_Enable_A_Robust_Classificat...
# what is main advantage of STNets? deepset/roberta-base-squad2-distilled 4          Applications_of_the_Streaming_Networks.pdf
#                                                                         5                    arxiv_streaming_networks_ext.pdf
#                                                                         6                                        cvpr2020.pdf
#                                                                         7   Streaming_Networks_Enable_A_Robust_Classificat...
#                                   default                               12         Applications_of_the_Streaming_Networks.pdf
#                                                                         13                   arxiv_streaming_networks_ext.pdf
#                                                                         14                                       cvpr2020.pdf
#                                                                         15  Streaming_Networks_Enable_A_Robust_Classificat...
#
#                                                                                                                        answer  \
# question                          model name
# How to describe STNet in short?   deepset/roberta-base-squad2-distilled 0                                Streaming net- works
#                                                                         1                                   Streaming Network
#                                                                         2                                  Streaming networks
#                                                                         3                                     pseudo-conv net
#                                   default                               16                                      hybrid STnets
#                                                                         17                        Kullback–Leibler divergence
#                                                                         18                                          5- stream
#                                                                         19                                      Streaming Net
# what are key features of STNets?  deepset/roberta-base-squad2-distilled 8   capable of recognition of zero noise- corrupte...
#                                                                         9              hard- wired and input-induced sparsity
#                                                                         10  capable of recognizing zero noise- corrupted i...
#                                                                         11                           images without any noise
#                                   default                               20  lighting or weather condition, speed, distance...
#                                                                         21                                    higher capacity
#                                                                         22  capable of recognizing zero noise- corrupted i...
#                                                                         23       Spike- based strategies for rapid processing
# what is main advantage of STNets? deepset/roberta-base-squad2-distilled 4   robust recognition of corrupted images under v...
#                                                                         5                                    noise robustness
#                                                                         6   recognizing zero noise- corrupted images with ...
#                                                                         7                        state-of-the-art performance
#                                   default                               12                   recognition of low- light images
#                                                                         13                                    higher capacity
#                                                                         14                                  moderate accuracy
#                                                                         15     increase conv net robustness against the noise
#
#                                                                                score
# question                          model name
# How to describe STNet in short?   deepset/roberta-base-squad2-distilled 0   0.581112
#                                                                         1   0.114451
#                                                                         2   0.267675
#                                                                         3   0.539523
#                                   default                               16  0.570117
#                                                                         17  0.302576
#                                                                         18  0.726802
#                                                                         19  0.474929
# what are key features of STNets?  deepset/roberta-base-squad2-distilled 8   0.066198
#                                                                         9   0.669279
#                                                                         10  0.316081
#                                                                         11  0.009240
#                                   default                               20  0.537666
#                                                                         21  0.316742
#                                                                         22  0.059329
#                                                                         23  0.192970
# what is main advantage of STNets? deepset/roberta-base-squad2-distilled 4   0.382967
#                                                                         5   0.874971
#                                                                         6   0.342385
#                                                                         7   0.315538
#                                   default                               12  0.111861
#                                                                         13  0.696631
#                                                                         14  0.185213
#                                                                         15  0.166835
